# %% [markdown]
# # Plot the ClassyFire molecule classes against the ranking-changes (improvements)
#
# For each MS-tuple in MassBank the ClassyFire molecule class (superclass- and class-level) has been determined. We also can provide the rank of the correct molecular structure within each candidate set for each MS-tuple. Two rankings are given:
#
# 1) **Only MS**: Candidates are ranked based on the respective MS2 scoring method (MetFrag, SIRIUS or CFM-ID)
# 2) **LC-MS$^2$Struct**: Ranking based on the max-marginals integrating the MS2 and retention order (RO) scores
#
# The analysis here consideres the rank-improvements (LC-MS$^2$Struct over Only MS) aggregated for each ClassyFire class, i.e. at superclass-level or class-level.
#
# For the **LC-MS$^2$Struct** ranking we aggregated eight (8) marginals by averaging the output of eight (8) different SSVM.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import os
import glob
import itertools as it

from typing import Union, List, Optional

# RDKIT
from rdkit.Chem import MolFromSmiles, Draw
from rdkit.Chem.rdDepictor import Compute2DCoords
from rdkit.Chem.Draw import IPythonConsole

from ssvm_evaluation.utils import dict2fn
from ssvm_evaluation.plotting_utils import plot__02__a, plot__02__b

# %% [markdown]
# ## Load Results

# %%
def ndarray_converter(x: str):
    """
    Convert list with two items stored an a CSV as string into an NumPy array. 
    """
    rmin, rmax = x.strip("[]").split(",")
    return np.array([int(rmin), int(rmax)], dtype=int)

# %%
agg_setting = {
    "marg_agg_fun": "average",
    "cand_agg_id": "inchikey1"
}

# %% [markdown]
# ### SIRIUS (2D)

# %%
df = pd.DataFrame()

setting = {
    "ds": "*",
    "mol_feat": "FCFP__binary__all__2D",
    "mol_id": "cid",
    "ms2scorer": "sirius__norm",
    "ssvm_flavor": "default",
    "lloss_mode": "mol_feat_fps"
}

for fn in sorted(
    glob.iglob(os.path.join("massbank", dict2fn(setting), dict2fn(agg_setting, pref="combined"), "rank_improvements__csi.tsv"))
):
    df = pd.concat(
        (
            df,
            pd.read_csv(
                fn, sep="\t", converters={"rank_onlyms": ndarray_converter, "rank_msplrt": ndarray_converter}
            ).assign(ms2scorer="SIRIUS (2D)")
        ), 
        ignore_index=True
    )

# %% [markdown]
# ### SIRIUS (3D)

# %%
setting = {
    "ds": "*",
    "mol_feat": "FCFP__binary__all__3D",
    "mol_id": "cid",
    "ms2scorer": "sirius__norm",
    "ssvm_flavor": "default",
    "lloss_mode": "mol_feat_fps"
}

for fn in sorted(
    glob.iglob(os.path.join("massbank", dict2fn(setting), dict2fn(agg_setting, pref="combined"), "rank_improvements__csi.tsv"))
):
    df = pd.concat(
        (
            df,
            pd.read_csv(
                fn, sep="\t", converters={"rank_onlyms": ndarray_converter, "rank_msplrt": ndarray_converter}
            ).assign(ms2scorer="SIRIUS (3D)")
        ), 
        ignore_index=True
    )

# %% [markdown]
# ## Plot Results
#
# ### Performance for individual ClassyFire super-classes

# %%
tmp = {}

tmp["superclass"], superlevel = plot__02__a(
    df, min_class_support=50, ks=[1, 5, 20], sharey="col", topk_method="csi", fig_width=5, fig_height=5, colormap_name="fixed", 
    cf_level="superclass", label_rot_angle=90, n_samples=50_y_add
)    

for ext in ["pdf", "svg"]:
    plt.savefig(os.path.join(".", os.extsep.join(["plot_06__a", ext])))

# %%
__a__ = tmp["superclass"][(tmp["superclass"]["k"] == 1) & (tmp["superclass"]["ms2scorer"] == "SIRIUS (2D)")].round(1)
# print(np.array(__a__["top_k_p_improvement"].tolist()) @ np.array(__a__["n_class_support"].tolist()) / __a__["n_class_support"].sum())
__a__
# Out:
#               classyfire_superclass  top_k_p_onlyms  top_k_p_msplrt  \
# 0         Alkaloids and derivatives            38.4            39.4
# 1                        Benzenoids            28.7            27.9
# 2   Lipids and lipid-like molecules            23.6            24.1
# 3     Organic acids and derivatives            39.6            39.3
# 4        Organic nitrogen compounds            44.9            45.0
# 5          Organic oxygen compounds            29.0            30.0
# 6      Organoheterocyclic compounds            33.4            33.2
# 7  Phenylpropanoids and polyketides            24.5            24.3
#
#    top_k_p_improvement  n_cand  n_isomers  n_class_support  k    ms2scorer  \
# 0                  0.9  4979.0         11              131  1  SIRIUS (2D)
# 1                 -0.8   989.0          1              825  1  SIRIUS (2D)
# 2                  0.5    83.0          3             1090  1  SIRIUS (2D)
# 3                 -0.4   619.5          3              318  1  SIRIUS (2D)
# 4                  0.1   881.5          1               74  1  SIRIUS (2D)
# 5                  1.0    88.5          3              188  1  SIRIUS (2D)
# 6                 -0.2   982.0          1              622  1  SIRIUS (2D)
# 7                 -0.2   247.0          3              539  1  SIRIUS (2D)
#
#    improvement_in_n
# 0               1.2
# 1              -6.8
# 2               5.1
# 3              -1.2
# 4               0.1
# 5               1.9
# 6              -1.3
# 7              -1.0

# %%
__a__ = tmp["superclass"][(tmp["superclass"]["k"] == 1) & (tmp["superclass"]["ms2scorer"] == "SIRIUS (3D)")].round(1)
# print(np.array(__a__["top_k_p_improvement"].tolist()) @ np.array(__a__["n_class_support"].tolist()) / __a__["n_class_support"].sum())
__a__
# Out:
#                classyfire_superclass  top_k_p_onlyms  top_k_p_msplrt  \
# 16         Alkaloids and derivatives            38.7            42.0
# 17                        Benzenoids            28.7            28.5
# 18   Lipids and lipid-like molecules            23.6            29.3
# 19     Organic acids and derivatives            39.4            39.7
# 20        Organic nitrogen compounds            44.8            42.5
# 21          Organic oxygen compounds            28.7            34.4
# 22      Organoheterocyclic compounds            33.2            33.3
# 23  Phenylpropanoids and polyketides            24.5            26.6
#
#     top_k_p_improvement  n_cand  n_isomers  n_class_support  k    ms2scorer  \
# 16                  3.4  4979.0         11              131  1  SIRIUS (3D)
# 17                 -0.2   989.0          1              826  1  SIRIUS (3D)
# 18                  5.6    83.0          3             1090  1  SIRIUS (3D)
# 19                  0.3   606.0          3              317  1  SIRIUS (3D)
# 20                 -2.2   881.5          1               74  1  SIRIUS (3D)
# 21                  5.7    88.5          3              188  1  SIRIUS (3D)
# 22                  0.1   982.0          1              622  1  SIRIUS (3D)
# 23                  2.2   247.0          3              539  1  SIRIUS (3D)
#
#     improvement_in_n
# 16               4.4
# 17              -1.3
# 18              61.3
# 19               0.9
# 20              -1.6
# 21              10.7
# 22               0.3
# 23              11.7

# %% [markdown]
# ### Performance for individual ClassyFire classes

# %%
tmp["class"], superlevel = plot__02__a(
    df, min_class_support=50, ks=[1, 5, 20], sharey="col", topk_method="csi", fig_width=5, fig_height=5.25, colormap_name="fixed",
    cf_level="class", label_rot_angle=90, n_samples=50
)

for ext in ["pdf", "svg"]:
    plt.savefig(os.path.join(".", os.extsep.join(["extended_data__plot_06__a__class_level", ext])))

# %%
__a__ = tmp["class"][(tmp["class"]["k"] == 1) & (tmp["class"]["ms2scorer"] == "SIRIUS (2D)")].round(1)
__a__
# Out:
#                        classyfire_class  top_k_p_onlyms  top_k_p_msplrt  \
# 0   Benzene and substituted derivatives            30.4            29.6
# 1      Carboxylic acids and derivatives            37.9            38.1
# 2             Coumarins and derivatives            27.4            28.1
# 3                           Fatty Acyls            32.9            33.1
# 4                            Flavonoids            23.1            23.2
# 5                  Glycerophospholipids            19.1            19.9
# 6               Indoles and derivatives            23.5            23.6
# 7                         Isoflavonoids            21.0            20.9
# 8              Organonitrogen compounds            44.8            44.9
# 9                Organooxygen compounds            28.8            29.7
# 10                        Prenol lipids            28.7            28.9
# 11           Quinolines and derivatives            30.8            31.0
# 12                        Sphingolipids             4.1             3.8
# 13     Steroids and steroid derivatives            32.8            33.2
#
#     top_k_p_improvement  n_cand  n_isomers  n_class_support  k    ms2scorer  \
# 0                  -0.8  1022.5        1.0              640  1  SIRIUS (2D)
# 1                   0.2  2357.0        3.0              223  1  SIRIUS (2D)
# 2                   0.8   377.5        1.0               56  1  SIRIUS (2D)
# 3                   0.2  1157.0        3.0              127  1  SIRIUS (2D)
# 4                   0.2   166.0        3.0              288  1  SIRIUS (2D)
# 5                   0.8    75.0        2.0              514  1  SIRIUS (2D)
# 6                   0.1  2195.0        1.0               65  1  SIRIUS (2D)
# 7                  -0.0   354.0        1.0               57  1  SIRIUS (2D)
# 8                   0.1   881.5        1.0               74  1  SIRIUS (2D)
# 9                   0.9    88.5        3.0              188  1  SIRIUS (2D)
# 10                  0.2    69.0       12.0              209  1  SIRIUS (2D)
# 11                  0.2   916.5        1.0               58  1  SIRIUS (2D)
# 12                 -0.3    48.0        3.0               63  1  SIRIUS (2D)
# 13                  0.4   224.5       31.5              164  1  SIRIUS (2D)
#
#     improvement_in_n
# 0               -4.9
# 1                0.4
# 2                0.4
# 3                0.3
# 4                0.5
# 5                4.2
# 6                0.1
# 7               -0.0
# 8                0.1
# 9                1.7
# 10               0.4
# 11               0.1
# 12              -0.2
# 13               0.6

# %%
__a__ = tmp["class"][(tmp["class"]["k"] == 1) & (tmp["class"]["ms2scorer"] == "SIRIUS (3D)")].round(1)
__a__
# Out:
#                        classyfire_class  top_k_p_onlyms  top_k_p_msplrt  \
# 42  Benzene and substituted derivatives            30.4            30.3
# 43     Carboxylic acids and derivatives            37.9            39.3
# 44            Coumarins and derivatives            27.4            31.8
# 45                          Fatty Acyls            32.9            36.0
# 46                           Flavonoids            23.1            25.7
# 47                 Glycerophospholipids            19.1            23.6
# 48              Indoles and derivatives            23.5            22.6
# 49                        Isoflavonoids            21.0            22.3
# 50             Organonitrogen compounds            44.8            42.6
# 51               Organooxygen compounds            28.8            34.8
# 52                        Prenol lipids            28.7            39.3
# 53           Quinolines and derivatives            30.8            30.0
# 54                        Sphingolipids             4.1            12.7
# 55     Steroids and steroid derivatives            32.8            35.1
#
#     top_k_p_improvement  n_cand  n_isomers  n_class_support  k    ms2scorer  \
# 42                 -0.1  1022.5        1.0              640  1  SIRIUS (3D)
# 43                  1.4  2357.0        3.0              223  1  SIRIUS (3D)
# 44                  4.4   377.5        1.0               56  1  SIRIUS (3D)
# 45                  3.0  1157.0        3.0              127  1  SIRIUS (3D)
# 46                  2.7   166.0        3.0              288  1  SIRIUS (3D)
# 47                  4.6    75.0        2.0              514  1  SIRIUS (3D)
# 48                 -0.9  2195.0        1.0               65  1  SIRIUS (3D)
# 49                  1.3   354.0        1.0               57  1  SIRIUS (3D)
# 50                 -2.2   881.5        1.0               74  1  SIRIUS (3D)
# 51                  6.0    88.5        3.0              188  1  SIRIUS (3D)
# 52                 10.7    69.0       12.0              209  1  SIRIUS (3D)
# 53                 -0.7   916.5        1.0               58  1  SIRIUS (3D)
# 54                  8.7    48.0        3.0               63  1  SIRIUS (3D)
# 55                  2.3   224.5       31.5              164  1  SIRIUS (3D)
#
#     improvement_in_n
# 42              -0.5
# 43               3.2
# 44               2.5
# 45               3.9
# 46               7.7
# 47              23.4
# 48              -0.6
# 49               0.7
# 50              -1.6
# 51              11.2
# 52              22.3
# 53              -0.4
# 54               5.5
# 55               3.8

# %% [markdown]
# ### PubChemLite classes

# %%
tmp["pubchemlite"] = plot__02__b(
    df, min_class_support=50, ks=[1, 20], sharey="col", topk_method="csi", fig_width=5, fig_height=3.5, n_samples=50
)

for ext in ["pdf", "svg"]:
    plt.savefig(os.path.join(".", os.extsep.join(["plot_06__b", ext])))

# %%
tmp["pubchemlite"][(tmp["pubchemlite"]["k"] == 1) & (tmp["pubchemlite"]["ms2scorer"] == "CFM-ID")].round(1)
# Out:
#    pubchemlite_class  top_k_p_onlyms  top_k_p_msplrt  top_k_p_improvement  \
# 0       agroChemInfo             9.4            10.8                  1.5
# 1         bioPathway             5.6             8.3                  2.7
# 2    disorderDisease             4.6             7.1                  2.5
# 3      drugMedicInfo             4.2             6.0                  1.8
# 4        foodRelated             5.6             9.3                  3.7
# 5     identification             5.9             7.5                  1.7
# 6           knownUse             6.4             9.1                  2.8
# 7   noClassification            10.4            12.6                  2.2
# 8       pharmacoInfo             6.6             9.2                  2.6
# 9         safetyInfo             4.9             7.3                  2.4
# 10      toxicityInfo             4.9             6.8                  1.9
#
#     n_cand  n_isomers  n_class_support  k ms2scorer  improvement_in_n
# 0    537.0          1              513  1    CFM-ID               7.5
# 1    540.0          3             2090  1    CFM-ID              56.3
# 2    697.0          3             1324  1    CFM-ID              33.2
# 3    905.0          3              930  1    CFM-ID              16.7
# 4    684.0          1              380  1    CFM-ID              14.1
# 5    728.0          1              801  1    CFM-ID              13.3
# 6    569.0          3             2459  1    CFM-ID              68.0
# 7     94.0          1              821  1    CFM-ID              18.4
# 8    461.0          3             2395  1    CFM-ID              62.2
# 9    800.5          1             1980  1    CFM-ID              47.8
# 10   771.5          1             1690  1    CFM-ID              32.4

# %%
tmp["pubchemlite"][(tmp["pubchemlite"]["k"] == 1) & (tmp["pubchemlite"]["ms2scorer"] == "MetFrag")].round(1)
# Out:
#    pubchemlite_class  top_k_p_onlyms  top_k_p_msplrt  top_k_p_improvement  \
# 22      agroChemInfo             9.0            14.9                  5.9
# 23        bioPathway             5.4             8.8                  3.4
# 24   disorderDisease             3.7             6.9                  3.2
# 25     drugMedicInfo             4.0             6.8                  2.8
# 26       foodRelated             2.7             6.6                  3.9
# 27    identification             4.1             8.6                  4.5
# 28          knownUse             5.6             9.3                  3.8
# 29  noClassification            14.1            16.1                  1.9
# 30      pharmacoInfo             6.4             9.9                  3.5
# 31        safetyInfo             4.4             8.1                  3.7
# 32      toxicityInfo             4.3             7.7                  3.5
#
#     n_cand  n_isomers  n_class_support  k ms2scorer  improvement_in_n
# 22   537.0          1              513  1   MetFrag              30.1
# 23   540.0          3             2090  1   MetFrag              70.7
# 24   697.0          3             1324  1   MetFrag              43.0
# 25   905.0          3              930  1   MetFrag              26.2
# 26   684.0          1              380  1   MetFrag              14.8
# 27   728.0          1              801  1   MetFrag              36.2
# 28   569.0          3             2459  1   MetFrag              92.7
# 29    94.0          1              821  1   MetFrag              15.7
# 30   461.0          3             2395  1   MetFrag              83.7
# 31   800.5          1             1980  1   MetFrag              73.7
# 32   771.5          1             1690  1   MetFrag              58.7

# %%
tmp["pubchemlite"][(tmp["pubchemlite"]["k"] == 1) & (tmp["pubchemlite"]["ms2scorer"] == "SIRIUS")].round(1)
# Out:
#    pubchemlite_class  top_k_p_onlyms  top_k_p_msplrt  top_k_p_improvement  \
# 44      agroChemInfo            36.5            36.6                  0.1
# 45        bioPathway            33.4            33.6                  0.2
# 46   disorderDisease            36.6            36.7                  0.0
# 47     drugMedicInfo            38.7            38.7                  0.0
# 48       foodRelated            36.4            36.1                 -0.3
# 49    identification            40.0            40.0                  0.0
# 50          knownUse            33.2            33.3                  0.1
# 51  noClassification            20.3            20.2                 -0.1
# 52      pharmacoInfo            33.4            33.5                  0.1
# 53        safetyInfo            34.6            34.5                 -0.1
# 54      toxicityInfo            35.6            35.5                 -0.1
#
#     n_cand  n_isomers  n_class_support  k ms2scorer  improvement_in_n
# 44   537.0          1              513  1    SIRIUS               0.7
# 45   540.0          3             2090  1    SIRIUS               3.1
# 46   697.0          3             1324  1    SIRIUS               0.7
# 47   905.0          3              930  1    SIRIUS               0.3
# 48   684.0          1              380  1    SIRIUS              -1.3
# 49   728.0          1              801  1    SIRIUS               0.1
# 50   569.0          3             2459  1    SIRIUS               1.6
# 51    94.0          1              821  1    SIRIUS              -1.1
# 52   461.0          3             2395  1    SIRIUS               1.7
# 53   800.5          1             1980  1    SIRIUS              -2.7
# 54   771.5          1             1690  1    SIRIUS              -1.8
